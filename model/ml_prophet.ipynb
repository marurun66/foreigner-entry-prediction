# %%
#prophet 예측 분석

# %%
# 데이터 불러오기
import pandas as pd
df = pd.read_csv('data/df_top15.csv')

# %%
df
# Out:
#         년   월 국적지역    입국자수          날짜
# 0    2018   1   대만   78321  2018-01-01
# 1    2018   2   대만   90673  2018-02-01
# 2    2018   3   대만   96811  2018-03-01
# 3    2018   4   대만  107719  2018-04-01
# 4    2018   5   대만   91102  2018-05-01
# ..    ...  ..  ...     ...         ...
# 712  2024   8   홍콩   61592  2024-08-01
# 713  2024   9   홍콩   39815  2024-09-01
# 714  2024  10   홍콩   52005  2024-10-01
# 715  2024  11   홍콩   46366  2024-11-01
# 716  2024  12   홍콩   58347  2024-12-01
#
# [717 rows x 5 columns]

# %%
df['날짜'] = pd.to_datetime(df['날짜'])

# %%
#년,월 컬럼은 삭제
df = df[['날짜', '국적지역', '입국자수']]

# %%
df['국적지역'].unique()
# Out:
# array(['대만', '러시아', '말레이시아', '미국', '베트남', '싱가포르', '영국', '오스트레일리아',
#        '인도네시아', '일본', '중국', '캐나다', '태국', '필리핀', '홍콩'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      717 non-null    datetime64[ns]
#  1   국적지역    717 non-null    object
#  2   입국자수    717 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 16.9+ KB

# %%
df
# Out:
#             날짜 국적지역    입국자수
# 0   2018-01-01   대만   78321
# 1   2018-02-01   대만   90673
# 2   2018-03-01   대만   96811
# 3   2018-04-01   대만  107719
# 4   2018-05-01   대만   91102
# ..         ...  ...     ...
# 712 2024-08-01   홍콩   61592
# 713 2024-09-01   홍콩   39815
# 714 2024-10-01   홍콩   52005
# 715 2024-11-01   홍콩   46366
# 716 2024-12-01   홍콩   58347
#
# [717 rows x 3 columns]

# %%
# 특정국가로만 해보기
select_country = "싱가포르"
select_df = df[df["국적지역"] == select_country].copy()

# %%
#날짜를 인덱스로 설정
select_df.set_index('날짜', inplace=True)

# %%
select_df
# Out:
#             국적지역   입국자수
# 날짜
# 2018-01-01  싱가포르   9691
# 2018-02-01  싱가포르   9131
# 2018-03-01  싱가포르  22221
# 2018-04-01  싱가포르  21170
# 2018-05-01  싱가포르  19804
# 2018-06-01  싱가포르  23153
# 2018-07-01  싱가포르  11559
# 2018-08-01  싱가포르  11877
# 2018-09-01  싱가포르  15388
# 2018-10-01  싱가포르  21827
# 2018-11-01  싱가포르  26023
# 2018-12-01  싱가포르  40515
# 2019-01-01  싱가포르   9895
# 2019-02-01  싱가포르   9845
# 2019-03-01  싱가포르  22158
# 2019-04-01  싱가포르  23354
# 2019-05-01  싱가포르  20164
# 2019-06-01  싱가포르  24778
# 2019-07-01  싱가포르  11043
# 2019-08-01  싱가포르  13054
# 2019-09-01  싱가포르  17790
# 2019-10-01  싱가포르  24761
# 2019-11-01  싱가포르  27624
# 2019-12-01  싱가포르  42270
# 2023-01-01  싱가포르  13404
# 2023-02-01  싱가포르  12217
# 2023-03-01  싱가포르  34403
# 2023-04-01  싱가포르  31210
# 2023-05-01  싱가포르  30642
# 2023-06-01  싱가포르  35449
# 2023-07-01  싱가포르  13424
# 2023-08-01  싱가포르  15170
# 2023-09-01  싱가포르  27000
# 2023-10-01  싱가포르  34795
# 2023-11-01  싱가포르  44540
# 2023-12-01  싱가포르  56482
# 2024-01-01  싱가포르  14098
# 2024-02-01  싱가포르  15355
# 2024-03-01  싱가포르  38954
# 2024-04-01  싱가포르  32556
# 2024-05-01  싱가포르  37384
# 2024-06-01  싱가포르  34226
# 2024-07-01  싱가포르  14151
# 2024-08-01  싱가포르  17369
# 2024-09-01  싱가포르  26113
# 2024-10-01  싱가포르  40940
# 2024-11-01  싱가포르  43682
# 2024-12-01  싱가포르  61661

# %%
df_prophet = select_df[['입국자수']].reset_index()

# %%
df_prophet
# Out:
#            날짜   입국자수
# 0  2018-01-01   9691
# 1  2018-02-01   9131
# 2  2018-03-01  22221
# 3  2018-04-01  21170
# 4  2018-05-01  19804
# 5  2018-06-01  23153
# 6  2018-07-01  11559
# 7  2018-08-01  11877
# 8  2018-09-01  15388
# 9  2018-10-01  21827
# 10 2018-11-01  26023
# 11 2018-12-01  40515
# 12 2019-01-01   9895
# 13 2019-02-01   9845
# 14 2019-03-01  22158
# 15 2019-04-01  23354
# 16 2019-05-01  20164
# 17 2019-06-01  24778
# 18 2019-07-01  11043
# 19 2019-08-01  13054
# 20 2019-09-01  17790
# 21 2019-10-01  24761
# 22 2019-11-01  27624
# 23 2019-12-01  42270
# 24 2023-01-01  13404
# 25 2023-02-01  12217
# 26 2023-03-01  34403
# 27 2023-04-01  31210
# 28 2023-05-01  30642
# 29 2023-06-01  35449
# 30 2023-07-01  13424
# 31 2023-08-01  15170
# 32 2023-09-01  27000
# 33 2023-10-01  34795
# 34 2023-11-01  44540
# 35 2023-12-01  56482
# 36 2024-01-01  14098
# 37 2024-02-01  15355
# 38 2024-03-01  38954
# 39 2024-04-01  32556
# 40 2024-05-01  37384
# 41 2024-06-01  34226
# 42 2024-07-01  14151
# 43 2024-08-01  17369
# 44 2024-09-01  26113
# 45 2024-10-01  40940
# 46 2024-11-01  43682
# 47 2024-12-01  61661

# %%
df_prophet.columns = ['ds', 'y']  # Prophet 모델용 컬럼명 변경

# %%
df_prophet
# Out:
#            ds      y
# 0  2018-01-01   9691
# 1  2018-02-01   9131
# 2  2018-03-01  22221
# 3  2018-04-01  21170
# 4  2018-05-01  19804
# 5  2018-06-01  23153
# 6  2018-07-01  11559
# 7  2018-08-01  11877
# 8  2018-09-01  15388
# 9  2018-10-01  21827
# 10 2018-11-01  26023
# 11 2018-12-01  40515
# 12 2019-01-01   9895
# 13 2019-02-01   9845
# 14 2019-03-01  22158
# 15 2019-04-01  23354
# 16 2019-05-01  20164
# 17 2019-06-01  24778
# 18 2019-07-01  11043
# 19 2019-08-01  13054
# 20 2019-09-01  17790
# 21 2019-10-01  24761
# 22 2019-11-01  27624
# 23 2019-12-01  42270
# 24 2023-01-01  13404
# 25 2023-02-01  12217
# 26 2023-03-01  34403
# 27 2023-04-01  31210
# 28 2023-05-01  30642
# 29 2023-06-01  35449
# 30 2023-07-01  13424
# 31 2023-08-01  15170
# 32 2023-09-01  27000
# 33 2023-10-01  34795
# 34 2023-11-01  44540
# 35 2023-12-01  56482
# 36 2024-01-01  14098
# 37 2024-02-01  15355
# 38 2024-03-01  38954
# 39 2024-04-01  32556
# 40 2024-05-01  37384
# 41 2024-06-01  34226
# 42 2024-07-01  14151
# 43 2024-08-01  17369
# 44 2024-09-01  26113
# 45 2024-10-01  40940
# 46 2024-11-01  43682
# 47 2024-12-01  61661

# %%
# Prophet 모델 학습
from prophet import Prophet

prophet_model =  Prophet(
    yearly_seasonality=True,    # 연도별 계절성 반영
    weekly_seasonality=False,   # 주별 계절성 제거
    daily_seasonality=False,    # 일별 계절성 제거
    seasonality_mode="multiplicative"  # 계절성을 곱셈 방식으로 적용 (트렌드 반영 강화)
)
prophet_model.fit(df_prophet)
# Out:
# 17:50:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:50:57 - cmdstanpy - INFO - Chain [1] done processing

# %%
# 예측할 기간 생성
future = prophet_model.make_future_dataframe(periods=24, freq='M')
forescast = prophet_model.predict(future)
# Out:
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(

# %%
forescast['yhat'] = forescast['yhat'].astype(int)
forescast[['ds', 'yhat']]
# Out:
#            ds   yhat
# 0  2018-01-01   9152
# 1  2018-02-01   7877
# 2  2018-03-01  22359
# 3  2018-04-01  20532
# 4  2018-05-01  20470
# ..        ...    ...
# 67 2026-07-31  19551
# 68 2026-08-31  32837
# 69 2026-09-30  36804
# 70 2026-10-31  53155
# 71 2026-11-30  70331
#
# [72 rows x 2 columns]

# %%
#2025 이후 데이터만보기
forescast[['ds', 'yhat']].tail(24)
# Out:
#            ds   yhat
# 48 2024-12-31  14875
# 49 2025-01-31  17845
# 50 2025-02-28  36559
# 51 2025-03-31  38193
# 52 2025-04-30  30444
# 53 2025-05-31  43245
# 54 2025-06-30  17366
# 55 2025-07-31  18506
# 56 2025-08-31  30437
# 57 2025-09-30  36112
# 58 2025-10-31  49376
# 59 2025-11-30  66253
# 60 2025-12-31  15430
# 61 2026-01-31  20412
# 62 2026-02-28  37873
# 63 2026-03-31  41360
# 64 2026-04-30  30480
# 65 2026-05-31  47463
# 66 2026-06-30  18789
# 67 2026-07-31  19551
# 68 2026-08-31  32837
# 69 2026-09-30  36804
# 70 2026-10-31  53155
# 71 2026-11-30  70331

# %%
#실제 23,24년 데이터
select_df['입국자수'].tail(24)
# Out:
# 날짜
# 2023-01-01    13404
# 2023-02-01    12217
# 2023-03-01    34403
# 2023-04-01    31210
# 2023-05-01    30642
# 2023-06-01    35449
# 2023-07-01    13424
# 2023-08-01    15170
# 2023-09-01    27000
# 2023-10-01    34795
# 2023-11-01    44540
# 2023-12-01    56482
# 2024-01-01    14098
# 2024-02-01    15355
# 2024-03-01    38954
# 2024-04-01    32556
# 2024-05-01    37384
# 2024-06-01    34226
# 2024-07-01    14151
# 2024-08-01    17369
# 2024-09-01    26113
# 2024-10-01    40940
# 2024-11-01    43682
# 2024-12-01    61661
# Name: 입국자수, dtype: int64

# %%
#한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


plt.rcParams['font.family'] = 'NanumGothic'  # 리눅스에서 한글 폰트 사용

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
#그래프로 확인
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(select_df.index, select_df['입국자수'], label='실제')
plt.plot(forescast['ds'], forescast['yhat'], label='예측')
plt.legend()
plt.show()

# %% [markdown]
# # 전체국가 예측

# %%
#### 전체국가 대상 예측###

# %%
import pandas as pd

# %%
df=pd.read_csv('../data/df_top15.csv')

# %%
df
# Out:
#         년   월 국적지역    입국자수          날짜
# 0    2018   1   대만   78321  2018-01-01
# 1    2018   2   대만   90673  2018-02-01
# 2    2018   3   대만   96811  2018-03-01
# 3    2018   4   대만  107719  2018-04-01
# 4    2018   5   대만   91102  2018-05-01
# ..    ...  ..  ...     ...         ...
# 712  2024   8   홍콩   61592  2024-08-01
# 713  2024   9   홍콩   39815  2024-09-01
# 714  2024  10   홍콩   52005  2024-10-01
# 715  2024  11   홍콩   46366  2024-11-01
# 716  2024  12   홍콩   58347  2024-12-01
#
# [717 rows x 5 columns]

# %%
df['날짜'] = pd.to_datetime(df['날짜'])

# %%
#년,월 컬럼은 삭제
df = df[['날짜', '국적지역', '입국자수']]

# %%
df
# Out:
#             날짜 국적지역    입국자수
# 0   2018-01-01   대만   78321
# 1   2018-02-01   대만   90673
# 2   2018-03-01   대만   96811
# 3   2018-04-01   대만  107719
# 4   2018-05-01   대만   91102
# ..         ...  ...     ...
# 712 2024-08-01   홍콩   61592
# 713 2024-09-01   홍콩   39815
# 714 2024-10-01   홍콩   52005
# 715 2024-11-01   홍콩   46366
# 716 2024-12-01   홍콩   58347
#
# [717 rows x 3 columns]

# %%
#전체 국가 대상으로 prophet 예측
from prophet import Prophet
import pandas as pd


# 모든 국가별 예측 결과를 저장할 리스트
all_forecasts = []

# 국가별로 Prophet 예측 수행
for country in df["국적지역"].unique():
    # 국가별 데이터 필터링
    df_country = df[df["국적지역"] == country][["날짜", "입국자수"]].rename(columns={"날짜": "ds", "입국자수": "y"})

    # 데이터 개수가 너무 적으면 스킵
    if df_country.shape[0] < 2:
        print(f"⚠️ {country}: 데이터 부족으로 예측 불가")
        continue

    # Prophet 모델 초기화 및 학습
    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        seasonality_mode="multiplicative",
    )
    model.fit(df_country)

    # 예측할 기간 설정 (24개월 예측)
    future = model.make_future_dataframe(periods=24, freq="M")

    # 예측 수행
    forecast = model.predict(future)

    # 예측 결과 정리
    forecast["국적지역"] = country
    forecast = forecast[["국적지역", "ds", "yhat", "yhat_lower", "yhat_upper"]]

    # 리스트에 추가
    all_forecasts.append(forecast)

# 모든 국가의 예측 결과를 하나의 데이터프레임으로 결합
final_forecast_df = pd.concat(all_forecasts, ignore_index=True)

final_forecast_df
# Out:
# 21:17:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:30 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:30 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:30 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:30 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:30 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 21:17:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:17:31 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
#      국적지역         ds          yhat    yhat_lower     yhat_upper
# 0      대만 2018-01-01  69550.712988  47143.865242   92442.577238
# 1      대만 2018-02-01  79099.423050  57398.765788  101364.491401
# 2      대만 2018-03-01  89247.675989  68627.772385  111884.770808
# 3      대만 2018-04-01  99119.272010  78356.102569  119542.060182
# 4      대만 2018-05-01  90267.700168  68562.897534  111970.713699
# ...   ...        ...           ...           ...            ...
# 1072   홍콩 2026-07-31  37816.585318  28500.575416   47243.837361
# 1073   홍콩 2026-08-31  32457.224757  23113.451754   41687.863454
# 1074   홍콩 2026-09-30  39486.777083  30068.083479   48945.136519
# 1075   홍콩 2026-10-31  33339.490481  23367.432094   42416.041221
# 1076   홍콩 2026-11-30  32979.025803  23136.658019   42361.588563
#
# [1077 rows x 5 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# 평가 결과 저장할 리스트
evaluation_results = []

# 국가별 평가 수행
for country in df["국적지역"].unique():
    # 실제값과 예측값 필터링
    actual = df[df["국적지역"] == country][["날짜", "입국자수"]].rename(columns={"날짜": "ds"})
    predicted = final_forecast_df[final_forecast_df["국적지역"] == country][["ds", "yhat"]]

    # 예측값과 실제값 병합
    merged_df = pd.merge(actual, predicted, on="ds", how="inner")

    # 예측값 및 실제값 배열 추출
    y_actual = merged_df["입국자수"].values
    y_pred = merged_df["yhat"].values

    # MAPE 계산
    mape = np.mean(np.abs((y_actual - y_pred) / y_actual)) * 100

    # RMSE 계산
    rmse = np.sqrt(mean_squared_error(y_actual, y_pred))

    # MAE 계산
    mae = mean_absolute_error(y_actual, y_pred)

    # 결과 저장
    evaluation_results.append({"국적지역": country, "MAPE(%)": mape, "RMSE": rmse, "MAE": mae})

# 결과를 데이터프레임으로 변환
evaluation_df = pd.DataFrame(evaluation_results)

# MAPE(%)가 큰 순서로 정렬하여 결과 확인
evaluation_df.sort_values("MAPE(%)", ascending=False)
# Out:
#        국적지역    MAPE(%)           RMSE           MAE
# 10       중국  52.398443  106668.761374  92651.057276
# 9        일본  15.509912   38168.114204  30846.805740
# 0        대만  15.077250   16479.702331  13661.328506
# 13      필리핀  14.813428    6039.593398   5078.548504
# 14       홍콩  14.802444    7324.241237   5895.758837
# 1       러시아  14.620120    3111.773388   2817.287962
# 6        영국  11.504450    1470.363147   1290.153650
# 2     말레이시아  10.811094    3304.111050   2701.130895
# 8     인도네시아  10.269340    2802.944922   2246.205722
# 4       베트남   9.330856    5096.219221   4168.067908
# 7   오스트레일리아   7.328044    1254.426317   1036.532739
# 12       태국   5.757981    2411.584306   2009.560136
# 11      캐나다   5.144713    1044.112958    809.291348
# 3        미국   4.823414    5472.508212   4099.253422
# 5      싱가포르   4.180198    1034.957325    816.113701

# %% [markdown]
# MAPE 해석
#
# 5% 미만 → 매우 정확한 모델
# 5~10% 미만 → 양호한 모델
# 10~20% 미만 → 보통 수준
# 20% 이상 → 모델 개선 필요

# %%
#중국은 개선필요

# %%
evaluation_df.to_csv('data/evaluation_df.csv', index=False)

# %%
final_forecast_df[final_forecast_df['국적지역']=='대만']
# Out:
#    국적지역         ds           yhat     yhat_lower     yhat_upper
# 0    대만 2018-01-01   69550.712988   49982.025426   91513.326692
# 1    대만 2018-02-01   79099.423050   57246.549790   99536.649053
# 2    대만 2018-03-01   89247.675989   67486.075523  111155.849907
# 3    대만 2018-04-01   99119.272010   76350.090472  120151.750988
# 4    대만 2018-05-01   90267.700168   69297.679787  111730.108892
# ..  ...        ...            ...            ...            ...
# 67   대만 2026-07-31  115304.751256   92538.515513  134225.210588
# 68   대만 2026-08-31  113511.985891   91251.346209  134727.131140
# 69   대만 2026-09-30  123821.571683  100844.518437  142534.234519
# 70   대만 2026-10-31  117589.359894   96013.268271  139031.267137
# 71   대만 2026-11-30   96397.631241   76548.580381  118995.539807
#
# [72 rows x 5 columns]

# %%
#'국적지역','ds','yhat' 컬럼만 추출
final_forecast_df[['국적지역','ds','yhat']]
# Out:
#      국적지역         ds          yhat
# 0      대만 2018-01-01  69550.712988
# 1      대만 2018-02-01  79099.423050
# 2      대만 2018-03-01  89247.675989
# 3      대만 2018-04-01  99119.272010
# 4      대만 2018-05-01  90267.700168
# ...   ...        ...           ...
# 1072   홍콩 2026-07-31  37816.585318
# 1073   홍콩 2026-08-31  32457.224757
# 1074   홍콩 2026-09-30  39486.777083
# 1075   홍콩 2026-10-31  33339.490481
# 1076   홍콩 2026-11-30  32979.025803
#
# [1077 rows x 3 columns]

# %%
#yhat 컬럼을 정수로 변환
final_forecast_df['yhat'] = final_forecast_df['yhat'].astype(int)

# %%
final_forecast_df
# Out:
#      국적지역         ds   yhat    yhat_lower     yhat_upper
# 0      대만 2018-01-01  69550  49982.025426   91513.326692
# 1      대만 2018-02-01  79099  57246.549790   99536.649053
# 2      대만 2018-03-01  89247  67486.075523  111155.849907
# 3      대만 2018-04-01  99119  76350.090472  120151.750988
# 4      대만 2018-05-01  90267  69297.679787  111730.108892
# ...   ...        ...    ...           ...            ...
# 1072   홍콩 2026-07-31  37816  27848.946283   47419.144441
# 1073   홍콩 2026-08-31  32457  23079.358303   41350.769072
# 1074   홍콩 2026-09-30  39486  29598.551085   48425.012357
# 1075   홍콩 2026-10-31  33339  23778.185061   42824.881689
# 1076   홍콩 2026-11-30  32979  23393.065017   42061.084650
#
# [1077 rows x 5 columns]

# %%
final_forecast_df['국적지역'].unique()
# Out:
# array(['대만', '러시아', '말레이시아', '미국', '베트남', '싱가포르', '영국', '오스트레일리아',
#        '인도네시아', '일본', '중국', '캐나다', '태국', '필리핀', '홍콩'], dtype=object)

# %%
import matplotlib.pyplot as plt

# 한글 폰트 설정 (리눅스 환경)
plt.rcParams["font.family"] = "NanumGothic"
plt.rcParams["axes.unicode_minus"] = False

# 전체 국가 리스트 추출
countries = df["국적지역"].unique()

# 모든 국가에 대해 그래프 출력
for select_country in countries:
    # 선택 국가의 입국자수 예측 결과 필터링
    forecast_select = final_forecast_df[final_forecast_df["국적지역"] == select_country]

    # 그래프 생성
    plt.figure(figsize=(15, 5))
    
    # 실제 데이터 플로팅
    plt.plot(
        df[df["국적지역"] == select_country]["날짜"],
        df[df["국적지역"] == select_country]["입국자수"],
        label="실제"
    )
    
    # 예측 결과 플로팅
    plt.plot(forecast_select["ds"], forecast_select["yhat"], label="예측")
    
    # 제목 및 범례 설정
    plt.title(f"Prophet {select_country}의 입국자수 예측")
    plt.legend()

    #그래프 저장
    plt.savefig(f'../image/prophet_{select_country}.png')
    
    # 그래프 출력
    plt.show()

# %%
final_forecast_df
# Out:
#      국적지역         ds   yhat    yhat_lower     yhat_upper
# 0      대만 2018-01-01  69550  49982.025426   91513.326692
# 1      대만 2018-02-01  79099  57246.549790   99536.649053
# 2      대만 2018-03-01  89247  67486.075523  111155.849907
# 3      대만 2018-04-01  99119  76350.090472  120151.750988
# 4      대만 2018-05-01  90267  69297.679787  111730.108892
# ...   ...        ...    ...           ...            ...
# 1072   홍콩 2026-07-31  37816  27848.946283   47419.144441
# 1073   홍콩 2026-08-31  32457  23079.358303   41350.769072
# 1074   홍콩 2026-09-30  39486  29598.551085   48425.012357
# 1075   홍콩 2026-10-31  33339  23778.185061   42824.881689
# 1076   홍콩 2026-11-30  32979  23393.065017   42061.084650
#
# [1077 rows x 5 columns]

# %%
final_forecast_df["방문년월"] = pd.to_datetime(final_forecast_df["ds"])

def transform_date(x):
    year = x.year
    month = x.month
    
    # 2024-12-31 이후의 경우: 월 + 1, 12월이면 연도도 +1
    if x >= pd.Timestamp("2024-12-31"):
        if month == 12:
            return year + 1, 1  # 다음 해 1월
        return year, month + 1  # 같은 해 다음 달
    
    return year, month

# 변환 적용
final_forecast_df[["년", "월"]] = final_forecast_df["방문년월"].apply(lambda x: pd.Series(transform_date(x)))

# 필요 없는 컬럼 제거 및 컬럼 순서 조정
final_forecast_df = final_forecast_df[["국적지역", "년", "월", "yhat"]]
final_forecast_df.rename(columns={"yhat": "입국자수"}, inplace=True)
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_36690/1941079859.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_forecast_df.rename(columns={"yhat": "입국자수"}, inplace=True)

# %%
final_forecast_df
# Out:
#      국적지역     년   월   입국자수
# 0      대만  2018   1  69550
# 1      대만  2018   2  79099
# 2      대만  2018   3  89247
# 3      대만  2018   4  99119
# 4      대만  2018   5  90267
# ...   ...   ...  ..    ...
# 1072   홍콩  2026   8  37816
# 1073   홍콩  2026   9  32457
# 1074   홍콩  2026  10  39486
# 1075   홍콩  2026  11  33339
# 1076   홍콩  2026  12  32979
#
# [1077 rows x 4 columns]

# %%
#중국은 오차가 커서 XGBregressor모델로 예측수행하기로
#중국을 제외한다
final_forecast_df = final_forecast_df[final_forecast_df["국적지역"] != "중국"]

# %%
final_forecast_df
# Out:
#      국적지역     년   월   입국자수
# 0      대만  2018   1  69550
# 1      대만  2018   2  79099
# 2      대만  2018   3  89247
# 3      대만  2018   4  99119
# 4      대만  2018   5  90267
# ...   ...   ...  ..    ...
# 1072   홍콩  2026   8  37816
# 1073   홍콩  2026   9  32457
# 1074   홍콩  2026  10  39486
# 1075   홍콩  2026  11  33339
# 1076   홍콩  2026  12  32979
#
# [1005 rows x 4 columns]

# %%
#저장
final_forecast_df.to_csv('data/df_top14_prophet.csv', index=False)

# %%
#모델 저장
import joblib

joblib.dump(prophet_model, 'model/prophet_model.pkl')

# %%
#지도 보여주기용으로 전체국가 대상으로 prophet 예측

# %%
#22~24년 데이터로만 학습시켰던 초기 분석내용 ######

# %%
# 25~26년 예상결과 값이 22~24년에 비해 너무 높게 나옴
# 모델 과대 성장 방지를 위한 조절
#성장 모델 변경 → growth='logistic'
#상한값(cap) 설정 → 최대 입국자 수의 **110%**로 제한
#과대 성장 방지를 위한 변곡점 민감도 조절 → changepoint_prior_scale=0.05

# %%
# 일본 데이터만 필터링
df_japan = df[df["국적지역"] == "일본"].copy()
df_prophet1 = df_japan[['입국자수']].reset_index()

df_prophet1.columns = ['ds', 'y']  # Prophet 모델용 컬럼명 변경
df_prophet1['ds'] = pd.to_datetime(df_prophet1['ds'])

# ✅ 상한값(cap)을 95% 분위수로 설정 (급격한 증가 방지)
df_prophet1["cap"] = df_prophet1["y"].quantile(0.95) * 1.05

# 하한값(floor) 설정 (2024년 최소값)
# 2024년 데이터 중 최소 입국자 수 찾기
floor_value_2024 = df_prophet1[(df_prophet1['ds'] >= '2024-01-01') & (df_prophet1['ds'] <= '2024-12-31')]["y"].min() * 1.5

# 하한값(floor) 적용
df_prophet1["floor"] = floor_value_2024

# 조절해서 모델 생성
model = Prophet(
    growth="logistic",
    yearly_seasonality=True,
    weekly_seasonality=False,
    daily_seasonality=False,
    seasonality_mode="multiplicative",
    changepoint_prior_scale=0.05  # 변곡점 민감도 증가 (급격한 하락 방지)
)

# 모델 학습
model.fit(df_prophet1)
# Out:
# 11:44:09 - cmdstanpy - INFO - Chain [1] start processing
# 11:44:09 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_prophet1
# Out:
#            ds       y         cap     floor
# 0  2018-01-01  170576  355752.075  220317.0
# 1  2018-02-01  170543  355752.075  220317.0
# 2  2018-03-01  296447  355752.075  220317.0
# 3  2018-04-01  215868  355752.075  220317.0
# 4  2018-05-01  229215  355752.075  220317.0
# 5  2018-06-01  237209  355752.075  220317.0
# 6  2018-07-01  232703  355752.075  220317.0
# 7  2018-08-01  319017  355752.075  220317.0
# 8  2018-09-01  249835  355752.075  220317.0
# 9  2018-10-01  292519  355752.075  220317.0
# 10 2018-11-01  301938  355752.075  220317.0
# 11 2018-12-01  260574  355752.075  220317.0
# 12 2019-01-01  210095  355752.075  220317.0
# 13 2019-02-01  215681  355752.075  220317.0
# 14 2019-03-01  377256  355752.075  220317.0
# 15 2019-04-01  292175  355752.075  220317.0
# 16 2019-05-01  288470  355752.075  220317.0
# 17 2019-06-01  284685  355752.075  220317.0
# 18 2019-07-01  277298  355752.075  220317.0
# 19 2019-08-01  334268  355752.075  220317.0
# 20 2019-09-01  253744  355752.075  220317.0
# 21 2019-10-01  251054  355752.075  220317.0
# 22 2019-11-01  260715  355752.075  220317.0
# 23 2019-12-01  257647  355752.075  220317.0
# 24 2023-01-01   70071  355752.075  220317.0
# 25 2023-02-01   96723  355752.075  220317.0
# 26 2023-03-01  194327  355752.075  220317.0
# 27 2023-04-01  130217  355752.075  220317.0
# 28 2023-05-01  185770  355752.075  220317.0
# 29 2023-06-01  198558  355752.075  220317.0
# 30 2023-07-01  213960  355752.075  220317.0
# 31 2023-08-01  267386  355752.075  220317.0
# 32 2023-09-01  252324  355752.075  220317.0
# 33 2023-10-01  257778  355752.075  220317.0
# 34 2023-11-01  280566  355752.075  220317.0
# 35 2023-12-01  197999  355752.075  220317.0
# 36 2024-01-01  146878  355752.075  220317.0
# 37 2024-02-01  187103  355752.075  220317.0
# 38 2024-03-01  341258  355752.075  220317.0
# 39 2024-04-01  231551  355752.075  220317.0
# 40 2024-05-01  281078  355752.075  220317.0
# 41 2024-06-01  260943  355752.075  220317.0
# 42 2024-07-01  245667  355752.075  220317.0
# 43 2024-08-01  327711  355752.075  220317.0
# 44 2024-09-01  313618  355752.075  220317.0
# 45 2024-10-01  326035  355752.075  220317.0
# 46 2024-11-01  343826  355752.075  220317.0
# 47 2024-12-01  253074  355752.075  220317.0

# %%
# 예측할 기간 생성
future = model.make_future_dataframe(periods=24, freq='M')
future["cap"] = df_prophet1["cap"].max()
future["floor"] = floor_value_2024
forescast1 = model.predict(future)
# Out:
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(

# %%
forescast1['yhat'] = forescast1['yhat'].astype(int)
forescast1[['ds', 'yhat']]
# Out:
#            ds    yhat
# 0  2018-01-01 -550378
# 1  2018-02-01 -517533
# 2  2018-03-01  507334
# 3  2018-04-01  -43918
# 4  2018-05-01  159087
# ..        ...     ...
# 67 2026-07-31  809942
# 68 2026-08-31  273986
# 69 2026-09-30  235852
# 70 2026-10-31  313479
# 71 2026-11-30   76953
#
# [72 rows x 2 columns]

# %%
#forescast와 forescast1 합쳐서비교
forescast[['ds', 'yhat']].tail(24).merge(
    forescast1[['ds', 'yhat']].tail(24), on='ds', suffixes=('_model1', '_model2')
)
# Out:
#            ds  yhat_model1  yhat_model2
# 0  2024-12-31       188827     -1484342
# 1  2025-01-31       229679      -663895
# 2  2025-02-28       424369      1463924
# 3  2025-03-31       230889      -178054
# 4  2025-04-30       320833       551573
# 5  2025-05-31       328216       381268
# 6  2025-06-30       343826       144185
# 7  2025-07-31       390634       980650
# 8  2025-08-31       359774       714201
# 9  2025-09-30       369460       720354
# 10 2025-10-31       398053       856838
# 11 2025-11-30       285315      -207712
# 12 2025-12-31       230784     -1721542
# 13 2026-01-31       271759      -711496
# 14 2026-02-28       499809      1665023
# 15 2026-03-31       258667      -237816
# 16 2026-04-30       371281       616530
# 17 2026-05-31       386619       432026
# 18 2026-06-30       411170       159887
# 19 2026-07-31       452473      1103745
# 20 2026-08-31       413569       787667
# 21 2026-09-30       423475       778805
# 22 2026-10-31       458604       929032
# 23 2026-11-30       326637      -291910

# %%
df_japan
# Out:
#            국적지역    입국자수
# 날짜
# 2022-07-01   일본   13069
# 2022-08-01   일본   28734
# 2022-09-01   일본   28836
# 2022-10-01   일본   68687
# 2022-11-01   일본   64005
# 2022-12-01   일본   85693
# 2023-01-01   일본   70071
# 2023-02-01   일본   96723
# 2023-03-01   일본  194327
# 2023-04-01   일본  130217
# 2023-05-01   일본  185770
# 2023-06-01   일본  198558
# 2023-07-01   일본  213960
# 2023-08-01   일본  267386
# 2023-09-01   일본  252324
# 2023-10-01   일본  257778
# 2023-11-01   일본  280566
# 2023-12-01   일본  197999
# 2024-01-01   일본  146878
# 2024-02-01   일본  187103
# 2024-03-01   일본  341258
# 2024-04-01   일본  231551
# 2024-05-01   일본  281078
# 2024-06-01   일본  260943
# 2024-07-01   일본  245667
# 2024-08-01   일본  327711
# 2024-09-01   일본  313618
# 2024-10-01   일본  326035
# 2024-11-01   일본  343826
# 2024-12-01   일본  253074

# %%
# 모든 나라 예측
all_forecasts = []

# %%
countries = df['국적지역'].unique()

# %%
countries
# Out:
# array(['네덜란드', '네팔', '뉴질랜드', '대만', '독일', '러시아', '말레이시아', '멕시코', '몽골',
#        '미국', '미얀마', '베트남', '스페인', '싱가포르', '영국', '오스트레일리아', '우즈베키스탄',
#        '이탈리아', '인도', '인도네시아', '일본', '중국', '카자흐스탄', '캄보디아', '캐나다', '태국',
#        '튀르키예', '프랑스', '필리핀', '홍콩'], dtype=object)

# %%
df
# Out:
#             국적지역   입국자수
# 날짜
# 2022-07-01  네덜란드   2880
# 2022-08-01  네덜란드   2928
# 2022-09-01  네덜란드   2792
# 2022-10-01  네덜란드   3266
# 2022-11-01  네덜란드   2766
# ...          ...    ...
# 2024-08-01    홍콩  61592
# 2024-09-01    홍콩  39815
# 2024-10-01    홍콩  52005
# 2024-11-01    홍콩  46366
# 2024-12-01    홍콩  58347
#
# [897 rows x 2 columns]

# %%
df.reset_index(inplace=True)

# %%
df.isna().sum()
# Out:
# 날짜      0
# 국적지역    0
# 입국자수    0
# dtype: int64

# %%
df
# Out:
#             날짜  국적지역   입국자수
# 0   2022-07-01  네덜란드   2880
# 1   2022-08-01  네덜란드   2928
# 2   2022-09-01  네덜란드   2792
# 3   2022-10-01  네덜란드   3266
# 4   2022-11-01  네덜란드   2766
# ..         ...   ...    ...
# 892 2024-08-01    홍콩  61592
# 893 2024-09-01    홍콩  39815
# 894 2024-10-01    홍콩  52005
# 895 2024-11-01    홍콩  46366
# 896 2024-12-01    홍콩  58347
#
# [897 rows x 3 columns]

# %%
from prophet import Prophet
import pandas as pd

# 학습 데이터의 가장 최근 날짜 찾기
latest_date = df["날짜"].max()

# 상한값(cap) 설정 (국가별 최대값의 105%)
df["cap"] = df.groupby("국적지역")["입국자수"].transform(lambda x: x.max() * 1.05)

# 모든 국가별 예측 결과를 저장할 리스트
all_forecasts = []

# 각 국가별로 Prophet 모델 학습 및 예측
for country in df["국적지역"].unique():
    # 국가별 데이터 필터링
    df_country = df[df["국적지역"] == country][["날짜", "입국자수", "cap"]].rename(columns={"날짜": "ds", "입국자수": "y"})

    # 날짜 형식 변환
    df_country["ds"] = pd.to_datetime(df_country["ds"])

    # 데이터 개수가 너무 적으면 스킵
    if df_country.shape[0] < 2:
        print(f"⚠️ {country}: 데이터 부족으로 예측 불가")
        continue

    # Prophet 모델 초기화 (일본 데이터 설정 반영)
    model = Prophet(
        growth="logistic",  # 무한 성장 방지
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        seasonality_mode="multiplicative",  # 계절성을 곱셈 방식으로 적용 (트렌드 반영 강화)
        changepoint_prior_scale=0.03  # 변곡점 민감도 낮춤 (급격한 성장 방지)
    )

    # 모델 학습
    model.fit(df_country)

    # 향후 2년 예측
    future = model.make_future_dataframe(periods=12 * 2, freq="M")

    # 예측 구간에서도 동일한 cap 값 적용
    future["cap"] = df_country["cap"].max()

    # 예측 수행
    forecast = model.predict(future)

    # 미래 데이터만 선택 (과거 데이터 제거)
    forecast = forecast[forecast["ds"] > latest_date]

    # 국가명 컬럼을 추가
    forecast["국적지역"] = country

    # 필요한 컬럼만 선택
    forecast = forecast[["국적지역", "ds", "yhat", "yhat_lower", "yhat_upper"]]

    # 리스트에 추가
    all_forecasts.append(forecast)

# 모든 국가의 예측 결과를 하나의 데이터프레임으로 결합
final_forecast_df = pd.concat(all_forecasts, ignore_index=True)

# 결과 확인
final_forecast_df
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_28030/2932897192.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cap"] = df.groupby("국적지역")["입국자수"].transform(lambda x: x.max() * 1.05)
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:49 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:50 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:51 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:51 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:52 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:52 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:52 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:52 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
# 23:32:52 - cmdstanpy - INFO - Chain [1] start processing
# 23:32:52 - cmdstanpy - INFO - Chain [1] done processing
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/prophet/forecaster.py:1854: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
#      국적지역         ds          yhat    yhat_lower    yhat_upper
# 0    네덜란드 2024-12-31   3686.783347   3177.536190   4181.069200
# 1    네덜란드 2025-01-31   3200.643930   2668.531829   3676.225032
# 2    네덜란드 2025-02-28   7125.747213   6636.988811   7629.650526
# 3    네덜란드 2025-03-31   6645.316223   6141.980799   7130.649050
# 4    네덜란드 2025-04-30   5737.330882   5214.727980   6260.048582
# ..    ...        ...           ...           ...           ...
# 715    홍콩 2026-07-31  70485.237698  65228.853342  76697.014730
# 716    홍콩 2026-08-31  55840.190695  49808.023503  61673.031299
# 717    홍콩 2026-09-30  76588.717025  70290.627966  82459.161489
# 718    홍콩 2026-10-31  72814.778638  66326.216395  78404.836902
# 719    홍콩 2026-11-30  71450.371289  65498.968067  77298.917185
#
# [720 rows x 5 columns]

# %%
# 모든 국가의 예측 결과를 하나의 데이터프레임으로 결합
final_forecast_df = pd.concat(all_forecasts, ignore_index=True)

# %%
final_forecast_df
# Out:
#      국적지역         ds          yhat    yhat_lower    yhat_upper
# 0    네덜란드 2024-12-31   3686.783347   3177.536190   4181.069200
# 1    네덜란드 2025-01-31   3200.643930   2668.531829   3676.225032
# 2    네덜란드 2025-02-28   7125.747213   6636.988811   7629.650526
# 3    네덜란드 2025-03-31   6645.316223   6141.980799   7130.649050
# 4    네덜란드 2025-04-30   5737.330882   5214.727980   6260.048582
# ..    ...        ...           ...           ...           ...
# 715    홍콩 2026-07-31  70485.237698  65228.853342  76697.014730
# 716    홍콩 2026-08-31  55840.190695  49808.023503  61673.031299
# 717    홍콩 2026-09-30  76588.717025  70290.627966  82459.161489
# 718    홍콩 2026-10-31  72814.778638  66326.216395  78404.836902
# 719    홍콩 2026-11-30  71450.371289  65498.968067  77298.917185
#
# [720 rows x 5 columns]

# %%
final_forecast_df[final_forecast_df['국적지역']=='미국']
# Out:
#     국적지역         ds           yhat     yhat_lower     yhat_upper
# 216   미국 2024-12-31   81764.085063   76056.117066   87633.230833
# 217   미국 2025-01-31   89411.941467   83847.099601   95122.548744
# 218   미국 2025-02-28  139312.909048  133788.262728  144941.739239
# 219   미국 2025-03-31  181449.673770  175670.542528  187056.407604
# 220   미국 2025-04-30  154655.612855  148894.273354  160509.688310
# 221   미국 2025-05-31  183447.468534  177535.320823  189192.938612
# 222   미국 2025-06-30  151992.192267  146134.898236  157491.643186
# 223   미국 2025-07-31  120472.138684  114382.835802  126412.986582
# 224   미국 2025-08-31  145475.448099  139584.079083  150700.717344
# 225   미국 2025-09-30  164223.389154  158126.654846  169949.776513
# 226   미국 2025-10-31  145288.870731  139758.811704  151084.106090
# 227   미국 2025-11-30  120064.865798  114445.878180  125632.379196
# 228   미국 2025-12-31   86704.131896   80821.073768   92187.868835
# 229   미국 2026-01-31  100771.809474   94662.756256  105833.069532
# 230   미국 2026-02-28  150384.624224  144473.924198  156044.390022
# 231   미국 2026-03-31  204683.892605  198717.249618  210744.997610
# 232   미국 2026-04-30  168069.118335  162237.059193  173934.770150
# 233   미국 2026-05-31  197928.205964  192505.797050  203866.176257
# 234   미국 2026-06-30  164689.422744  159248.923758  170812.538140
# 235   미국 2026-07-31  127974.746518  122181.095897  133602.009412
# 236   미국 2026-08-31  158582.951212  152966.433411  164029.120032
# 237   미국 2026-09-30  174590.342515  169309.709995  180427.128096
# 238   미국 2026-10-31  158270.963317  152102.069214  163948.721117
# 239   미국 2026-11-30  128202.614371  122534.562943  134587.937499

# %%
#final_forecast_df를 정수형으로 만들기
final_forecast_df['yhat'] = final_forecast_df['yhat'].astype(int)

# %%
final_forecast_df
# Out:
#      국적지역         ds   yhat    yhat_lower    yhat_upper
# 0    네덜란드 2024-12-31   3686   3177.536190   4181.069200
# 1    네덜란드 2025-01-31   3200   2668.531829   3676.225032
# 2    네덜란드 2025-02-28   7125   6636.988811   7629.650526
# 3    네덜란드 2025-03-31   6645   6141.980799   7130.649050
# 4    네덜란드 2025-04-30   5737   5214.727980   6260.048582
# ..    ...        ...    ...           ...           ...
# 715    홍콩 2026-07-31  70485  65228.853342  76697.014730
# 716    홍콩 2026-08-31  55840  49808.023503  61673.031299
# 717    홍콩 2026-09-30  76588  70290.627966  82459.161489
# 718    홍콩 2026-10-31  72814  66326.216395  78404.836902
# 719    홍콩 2026-11-30  71450  65498.968067  77298.917185
#
# [720 rows x 5 columns]

# %%
final_forecast_df.loc[final_forecast_df['국적지역']=='중국']
# Out:
#     국적지역         ds     yhat    yhat_lower    yhat_upper
# 504   중국 2024-12-31   157199  1.350517e+05  1.787869e+05
# 505   중국 2025-01-31   791133  7.705606e+05  8.116103e+05
# 506   중국 2025-02-28    65950  4.511193e+04  8.781619e+04
# 507   중국 2025-03-31   361463  3.412138e+05  3.825705e+05
# 508   중국 2025-04-30   376228  3.545908e+05  3.968583e+05
# 509   중국 2025-05-31   515689  4.948865e+05  5.383833e+05
# 510   중국 2025-06-30   572875  5.502001e+05  5.928478e+05
# 511   중국 2025-07-31   626501  6.065604e+05  6.481113e+05
# 512   중국 2025-08-31   568799  5.461900e+05  5.893058e+05
# 513   중국 2025-09-30   468498  4.455260e+05  4.883160e+05
# 514   중국 2025-10-31   388860  3.669287e+05  4.109017e+05
# 515   중국 2025-11-30   404251  3.837174e+05  4.271810e+05
# 516   중국 2025-12-31   -74914 -9.594152e+04 -5.459550e+04
# 517   중국 2026-01-31  1110704  1.088880e+06  1.132046e+06
# 518   중국 2026-02-28   -36847 -5.710325e+04 -1.383231e+04
# 519   중국 2026-03-31   334089  3.142084e+05  3.555926e+05
# 520   중국 2026-04-30   359670  3.382847e+05  3.816149e+05
# 521   중국 2026-05-31   530147  5.084254e+05  5.500839e+05
# 522   중국 2026-06-30   583871  5.626802e+05  6.061686e+05
# 523   중국 2026-07-31   636930  6.174251e+05  6.579516e+05
# 524   중국 2026-08-31   587300  5.671857e+05  6.080179e+05
# 525   중국 2026-09-30   473505  4.520381e+05  4.956028e+05
# 526   중국 2026-10-31   398474  3.762359e+05  4.193569e+05
# 527   중국 2026-11-30   410981  3.895270e+05  4.311093e+05

# %%
df.loc[df['국적지역']=='중국']
# Out:
#             날짜 국적지역    입국자수        cap
# 630 2022-07-01   중국   20013  569153.55
# 631 2022-08-01   중국   32060  569153.55
# 632 2022-09-01   중국   32054  569153.55
# 633 2022-10-01   중국   25826  569153.55
# 634 2022-11-01   중국   27411  569153.55
# 635 2022-12-01   중국   31036  569153.55
# 636 2023-01-01   중국   30141  569153.55
# 637 2023-02-01   중국   53337  569153.55
# 638 2023-03-01   중국   83868  569153.55
# 639 2023-04-01   중국  118139  569153.55
# 640 2023-05-01   중국  143796  569153.55
# 641 2023-06-01   중국  184234  569153.55
# 642 2023-07-01   중국  244056  569153.55
# 643 2023-08-01   중국  292811  569153.55
# 644 2023-09-01   중국  283265  569153.55
# 645 2023-10-01   중국  274703  569153.55
# 646 2023-11-01   중국  236156  569153.55
# 647 2023-12-01   중국  268460  569153.55
# 648 2024-01-01   중국  298029  569153.55
# 649 2024-02-01   중국  377260  569153.55
# 650 2024-03-01   중국  413005  569153.55
# 651 2024-04-01   중국  430303  569153.55
# 652 2024-05-01   중국  415260  569153.55
# 653 2024-06-01   중국  417915  569153.55
# 654 2024-07-01   중국  482341  569153.55
# 655 2024-08-01   중국  542051  569153.55
# 656 2024-09-01   중국  451496  569153.55
# 657 2024-10-01   중국  413920  569153.55
# 658 2024-11-01   중국  316817  569153.55
# 659 2024-12-01   중국  324872  569153.55

# %%
#국적지역, ds를 방문년월로 (yyyy-mm-dd -> yyyymm+1), yhat을 입국자수로 변경하여 저장
final_forecast_df["방문년월"] = pd.to_datetime(final_forecast_df["ds"])
final_forecast_df["방문년월"] = final_forecast_df["방문년월"].apply(lambda x: 
    str((x.year + 1) * 100 + 1) if x.month == 12 else str(x.year * 100 + x.month + 1)
)



final_forecast_df = final_forecast_df[["국적지역", "방문년월", "yhat"]]
final_forecast_df.rename(columns={"yhat": "입국자수"}, inplace=True)
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_28030/1431108815.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_forecast_df.rename(columns={"yhat": "입국자수"}, inplace=True)

# %%
final_forecast_df
# Out:
#      국적지역    방문년월   입국자수
# 0    네덜란드  202501   3686
# 1    네덜란드  202502   3200
# 2    네덜란드  202503   7125
# 3    네덜란드  202504   6645
# 4    네덜란드  202505   5737
# ..    ...     ...    ...
# 715    홍콩  202608  70485
# 716    홍콩  202609  55840
# 717    홍콩  202610  76588
# 718    홍콩  202611  72814
# 719    홍콩  202612  71450
#
# [720 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


plt.rcParams['font.family'] = 'NanumGothic'  # 리눅스에서 한글 폰트 사용

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

from matplotlib import pyplot as plt
import seaborn as sb

plt.figure(figsize=(12, 6))
sb.lineplot(data=final_forecast_df, x="방문년월", y="입국자수", hue="국적지역", ci=None)
plt.title("2025~2026년 국가별 월별 입국자 예측 추이")
plt.xlabel("월")
plt.ylabel("예측 입국자수")
plt.legend(title="국적지역", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_28030/3969971898.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sb.lineplot(data=final_forecast_df, x="방문년월", y="입국자수", hue="국적지역", ci=None)

# %%
# '방문년월'에서 연도와 월 분리
final_forecast_df['연도'] = final_forecast_df['방문년월'].astype(str).str[:4]
final_forecast_df['월'] = final_forecast_df['방문년월'].astype(str).str[4:].astype(int)

# 분기 매핑
season_mapping = {
    (3, 4, 5): "1분기 (봄 3~5월)",
    (6, 7, 8): "2분기 (여름 6~8월)",
    (9, 10, 11):"3분기 (가을 9~11월)",
    (12, 1, 2): "4분기 (겨울 12~2월)"
}

# 각 월에 대해 분기 매핑
def get_quarter(month):
    for key, value in season_mapping.items():
        if month in key:
            return value
    return None

final_forecast_df['분기'] = final_forecast_df['월'].apply(get_quarter)

# 연도-분기 컬럼 추가
final_forecast_df['연도분기'] = final_forecast_df['연도'] + "년 " + final_forecast_df['분기']

# 불필요한 컬럼 제거
final_forecast_df = final_forecast_df[['국적지역', '연도분기', '입국자수']]

# 같은 연도-분기별로 합산
df_grouped = final_forecast_df.groupby(['국적지역', '연도분기'], as_index=False)['입국자수'].sum()
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_28030/572851082.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_forecast_df['연도'] = final_forecast_df['방문년월'].astype(str).str[:4]
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_28030/572851082.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_forecast_df['월'] = final_forecast_df['방문년월'].astype(str).str[4:].astype(int)

# %%
final_forecast_df
# Out:
#      국적지역                  연도분기   입국자수
# 0    네덜란드  2025년 4분기 (겨울 12~2월)   3686
# 1    네덜란드  2025년 4분기 (겨울 12~2월)   3200
# 2    네덜란드    2025년 1분기 (봄 3~5월)   7125
# 3    네덜란드    2025년 1분기 (봄 3~5월)   6645
# 4    네덜란드    2025년 1분기 (봄 3~5월)   5737
# ..    ...                   ...    ...
# 715    홍콩   2026년 2분기 (여름 6~8월)  70485
# 716    홍콩  2026년 3분기 (가을 9~11월)  55840
# 717    홍콩  2026년 3분기 (가을 9~11월)  76588
# 718    홍콩  2026년 3분기 (가을 9~11월)  72814
# 719    홍콩  2026년 4분기 (겨울 12~2월)  71450
#
# [720 rows x 3 columns]

# %%
final_forecast_df.to_csv('data/prophet_df.csv', index=False)

# %%
#모델 저장
import joblib
joblib.dump(model, 'model/prophet_model.pkl')
# Out:
# ['model/prophet_model.pkl']
