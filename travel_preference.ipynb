# %%
import pandas as pd

# 데이터 생성
data = {
    "국가": [
        "네덜란드", "네팔", "뉴질랜드", "대만", "독일", "러시아", "말레이시아", "멕시코", "몽골", "미국",
        "미얀마", "베트남", "스페인", "싱가포르", "영국", "오스트레일리아", "우즈베키스탄", "이탈리아", "인도", "인도네시아",
        "일본", "중국", "카자흐스탄", "캄보디아", "캐나다", "태국", "튀르키예", "프랑스", "필리핀", "홍콩"
    ],
    "언어": [
        "네덜란드어", "네팔어", "영어", "중국어", "독일어", "러시아어", "말레이어", "스페인어", "몽골어", "영어",
        "미얀마어", "베트남어", "스페인어", "영어, 중국어", "영어", "영어", "우즈베크어", "이탈리아어", "힌디어, 영어", "인도네시아어",
        "일본어", "중국어", "카자흐어, 러시아어", "크메르어", "영어, 프랑스어", "태국어", "터키어", "프랑스어", "영어, 타갈로그어", "중국어, 영어"
    ],
    "여행 성향": [
        "전통문화 및 자연경관 탐방 선호", "등산 및 자연경관 탐방 선호", "자연경관 및 액티비티 선호", "미식 및 쇼핑 선호, 한류 관심",
        "역사 및 산업 관광 선호", "미식 및 쇼핑 선호, K-뷰티 관심", "한류 및 도심 관광 선호, 할랄 음식 관심", "K-팝 및 한류 문화 관심, 길거리 음식 탐방",
        "자연경관 및 힐링 여행 선호", "도시 관광 및 야경 선호, K-푸드 관심", "전통문화 및 불교 문화 관심", "한류 및 도심 관광 선호, 미식 관심",
        "문화 및 건축 관광 선호", "럭셔리 및 쇼핑 선호, 한류 관심", "도시 관광 및 역사 탐방 선호", "자연경관 및 힐링 여행 선호",
        "역사 및 전통문화 탐방 선호", "예술 및 문화 관광 선호", "전통문화 및 불교 유적 관심", "한류 및 도심 관광 선호",
        "쇼핑 및 음식 탐방 선호, 개별 여행 선호", "역사 유적지 방문 선호, 단체 여행 선호", "자연경관 및 역사 탐방 선호", "전통문화 및 불교 유적 탐방 선호",
        "자연경관 및 아웃도어 활동 선호", "미식 및 쇼핑 선호, 한류 관심", "역사 및 전통문화 탐방 선호", "문화 및 예술 관광 선호",
        "해변 및 휴양 관광 선호", "쇼핑 및 미식 선호, 한류 관심"
    ]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 데이터프레임 출력
df
# Out:
#          국가          언어                      여행 성향
# 0      네덜란드       네덜란드어          전통문화 및 자연경관 탐방 선호
# 1        네팔         네팔어            등산 및 자연경관 탐방 선호
# 2      뉴질랜드          영어             자연경관 및 액티비티 선호
# 3        대만         중국어          미식 및 쇼핑 선호, 한류 관심
# 4        독일         독일어              역사 및 산업 관광 선호
# 5       러시아        러시아어        미식 및 쇼핑 선호, K-뷰티 관심
# 6     말레이시아        말레이어    한류 및 도심 관광 선호, 할랄 음식 관심
# 7       멕시코        스페인어  K-팝 및 한류 문화 관심, 길거리 음식 탐방
# 8        몽골         몽골어            자연경관 및 힐링 여행 선호
# 9        미국          영어     도시 관광 및 야경 선호, K-푸드 관심
# 10      미얀마        미얀마어            전통문화 및 불교 문화 관심
# 11      베트남        베트남어       한류 및 도심 관광 선호, 미식 관심
# 12      스페인        스페인어              문화 및 건축 관광 선호
# 13     싱가포르     영어, 중국어         럭셔리 및 쇼핑 선호, 한류 관심
# 14       영국          영어           도시 관광 및 역사 탐방 선호
# 15  오스트레일리아          영어            자연경관 및 힐링 여행 선호
# 16   우즈베키스탄       우즈베크어            역사 및 전통문화 탐방 선호
# ...

# %%
#데이터 저장
df.to_csv("data/example_travel_preference.csv", index=False)
